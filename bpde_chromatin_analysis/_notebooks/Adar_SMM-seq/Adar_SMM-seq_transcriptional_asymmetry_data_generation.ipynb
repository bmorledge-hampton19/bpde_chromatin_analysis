# %% [markdown]
# ### Set up pipeline with basic imports, data directories, and file paths.

# %%
import os
from benbiohelpers.DataPipelineManagement.GenomeManager import getGenomeFastaFilePath
from bpde_chromatin_analysis.helper_scripts.BPDE_DataDir import getDataDir
from mutperiodpy.helper_scripts.UsefulFileSystemFunctions import getExternalDataDirectory as getMutperiodExternalDataDirectory, DataTypeStr
from benbiohelpers.FileSystemHandling.DirectoryHandling import getFilesInDirectory

hg19FastaFilePath = getGenomeFastaFilePath("hg19")
hg19GeneDesignationsFilePath = os.path.join(getMutperiodExternalDataDirectory(), "hg19", "hg19_protein_coding_genes",
                                            "hg19_protein_coding_genes_32658_bp_extended_ENCODE_blacklist_filtered.bed")

smmSeqDataDirectory = os.path.join(getDataDir(), "Adar_smm-seq")
smmSeqMutationsFilePath = getFilesInDirectory(smmSeqDataDirectory, DataTypeStr.mutations+".bed", searchRecursively=False)

# %% [markdown]
# ### Count mutations on the TS vs. NTS across 6 fractional bins + 3 flanking regions on either side.

# %%
from chromatinfeaturesanalysis.BinInGenes import binInGenes

binInGenes([smmSeqMutationsFilePath], hg19GeneDesignationsFilePath, filePathSuffix = "TS_vs_NTS", flankingBinNum = 3, flankingBinSize = 10886)

# %% [markdown]
# ### Fine-grain analysis

# %%
binInGenes([smmSeqMutationsFilePath], hg19GeneDesignationsFilePath, filePathSuffix = "TS_vs_NTS_fine-grain", flankingBinNum = 300, flankingBinSize = 108,
           geneFractionNum = 600)
